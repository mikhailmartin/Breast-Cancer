# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Навигация
#
# 1. [Анализ распределений](#Анализ-распределений)
#    - [2. Возраст](#2.-Возраст)
#    - [3. Семейное положение](#3.-Семейное-положение)
#    - [4. Если имеете супруга или партнёра, как долго вы живёте вместе (в годах)?](#4.-Если-имеете-супруга-или-партнёра,-как-долго-вы-живёте-вместе-(в-годах)?)
#    - [5. В какой семье Вы выросли?](#5.-В-какой-семье-Вы-выросли?)
#    - [6. Жив ли хотя бы один из Ваших родителей? (да/нет)](#6.-Жив-ли-хотя-бы-один-из-Ваших-родителей?-(да/нет))
#    - [7. Если да, как часто вы общаетесь?](#7.-Если-да,-как-часто-вы-общаетесь?)
#    - [8. Есть ли у Вас дети? (да/нет)](#8.-Есть-ли-у-Вас-дети?-(да/нет))
#    - [9. Сколько у Вас детей?](#9.-Сколько-у-Вас-детей?)
#    - [10. Есть ли у Вас совершеннолетние дети (да/нет)?](#10.-Есть-ли-у-Вас-совершеннолетние-дети-(да/нет)?)
#    - [11. Если да, как часто вы общаетесь? (с совершеннолетними детьми)](#11.-Если-да,-как-часто-вы-общаетесь?-(с-совершеннолетними-детьми))
#    - [12. Сколько человек живут вместе с Вами?](#12.-Сколько-человек-живут-вместе-с-Вами?)
#    - [13. Каковы Ваши взаимоотношения с соседями?](#13.-Каковы-Ваши-взаимоотношения-с-соседями?)
#    - [14. Как часто Вы встречаетесь с друзьями?](#14.-Как-часто-Вы-встречаетесь-с-друзьями?)
#    - [15. Есть ли у Вас домашние питомцы? (да/нет)](#15.-Есть-ли-у-Вас-домашние-питомцы?-(да/нет))
#    - [16. В течение последних 7 дней, как часто Вы практиковали тяжелые физические нагрузки?](#16.-В-течение-последних-7-дней,-как-часто-Вы-практиковали-тяжелые-физические-нагрузки?)
#    - [17. В течение последних 7 дней, как часто Вы практиковали умеренные физические нагрузки?](#17.-В-течение-последних-7-дней,-как-часто-Вы-практиковали-умеренные-физические-нагрузки?)
#    - [18. В течение последних 7 дней, как часто Вы ходили пешком минимум 10 минут без перерыва?](#18.-В-течение-последних-7-дней,-как-часто-Вы-ходили-пешком-минимум-10-минут-без-перерыва?)
#    - [19. Уровень Вашего образования?](#19.-Уровень-Вашего-образования?)
#    - [20. Каков уровень образования Вашего партнёра? (если применимо)](#20.-Каков-уровень-образования-Вашего-партнёра?-(если-применимо))
#    - [22. Как долго Вы проживаете в этом месте? (в годах)](#22.-Как-долго-Вы-проживаете-в-этом-месте?-(в-годах))
#    - [23. Каков тип Вашего дома?](#23.-Каков-тип-Вашего-дома?)
#    - [24. Если Вы живёте в многоквартирном доме, то на каком этаже?](#24.-Если-Вы-живёте-в-многоквартирном-доме,-то-на-каком-этаже?)
#    - [25. Каким транспортом Вы обычно пользуетесь?](#25.-Каким-транспортом-Вы-обычно-пользуетесь?)
#    - [26. Сколько времени занимает Ваш путь до работы в одну сторону?](#26.-Сколько-времени-занимает-Ваш-путь-до-работы-в-одну-сторону?)
#    - [27. Каков тип Вашей занятости?](#27.-Каков-тип-Вашей-занятости?)
#    - [28. Каковы Ваши предпочтения в пище?](#28.-Каковы-Ваши-предпочтения-в-пище?)
#    - [29. Каков тип Вашего питания?](#29.-Каков-тип-Вашего-питания?)
#    - [30. Вы курите? (да/нет)](#30.-Вы-курите?-(да/нет))
#    - [31. Количество родов](#31.-Количество-родов)
#    - [32. Количество прерванных беременностей](#32.-Количество-прерванных-беременностей)
#    - [33. Гинекологические заболевания (да/нет)](#33.-Гинекологические-заболевания-(да/нет))
#    - [34. Заболевания щитовидной железы (да/нет)](#34.-Заболевания-щитовидной-железы-(да/нет))
#    - [35. Наследственность (да/нет)](#35.-Наследственность-(да/нет))
# 2. [Точки данных с противоречивыми признаками](#Точки-данных-с-противоречивыми-признаками)
# 3. [Корреляция Пирсона между численными признаками](#Корреляция-Пирсона-между-численными-признаками)

# %%
import itertools

import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns

import utils
from utils import visualization as viz

# %%
RANDOM_STATE = 42

# %%
df = pd.read_excel(utils.constants.ETLED_DATA_PATH)

# %% [markdown]
# ## Анализ распределений
#
# [Навигация](#Навигация)

# %%
norm = (df[utils.constants.TARGET] == utils.constants.LABELS[0]).sum()
benign_tumor = (df[utils.constants.TARGET] == utils.constants.LABELS[1]).sum()
malignant_tumor = (df[utils.constants.TARGET] == utils.constants.LABELS[2]).sum()

viz.plot_distribution(norm, benign_tumor, malignant_tumor)

# %% [markdown]
# ### 2. Возраст
#
# [Навигация](#Навигация)

# %%
fig, ax = viz.num_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_2,
    target_colname=utils.constants.TARGET,
    value_range=(0, 125),
    figsize=(18, 6),
)
# Out:
# t-критерий Стьюдента: Выборки различимы (p-значение: 0.000)

# %% [markdown]
# ### 3. Семейное положение
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_3,
    target_colname=utils.constants.TARGET,
    figsize=(12, 6),
)
axes[0].set_xticks(axes[0].get_xticks(), axes[0].get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 4. Если имеете супруга или партнёра, как долго вы живёте вместе (в годах)?
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.num_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_4,
    target_colname=utils.constants.TARGET,
    figsize=(24, 6),
)
axes[2].set_xticks(axes[2].get_xticks(), axes[2].get_xticklabels(), rotation=15, ha='right')
plt.show()
# Out:
# t-критерий Стьюдента: Выборки различимы (p-значение: 0.000)

# %% [markdown]
# ### 5. В какой семье Вы выросли?
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_5,
    target_colname=utils.constants.TARGET,
    figsize=(24, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 6. Жив ли хотя бы один из Ваших родителей? (да/нет)
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_6,
    target_colname=utils.constants.TARGET,
    figsize=(12, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 7. Если да, как часто вы общаетесь?
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_7,
    target_colname=utils.constants.TARGET,
    figsize=(26, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 8. Есть ли у Вас дети? (да/нет)
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_8,
    target_colname=utils.constants.TARGET,
    figsize=(12, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 9. Сколько у Вас детей?
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.num_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_9,
    target_colname=utils.constants.TARGET,
    figsize=(24, 6),
    histplot_args={'discrete': True},
)
axes[2].set_xticks(axes[2].get_xticks(), axes[2].get_xticklabels(), rotation=15, ha='right')
plt.show()
# Out:
# t-критерий Стьюдента: Выборки различимы (p-значение: 0.007)

# %% [markdown]
# ### 10. Есть ли у Вас совершеннолетние дети (да/нет)?
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_10,
    target_colname=utils.constants.TARGET,
    figsize=(12, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 11. Если да, как часто вы общаетесь? (с совершеннолетними детьми)
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_11,
    target_colname=utils.constants.TARGET,
    figsize=(26, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 12. Сколько человек живут вместе с Вами?
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_12,
    target_colname=utils.constants.TARGET,
    figsize=(17, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 13. Каковы Ваши взаимоотношения с соседями?
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_13,
    target_colname=utils.constants.TARGET,
    figsize=(22, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 14. Как часто Вы встречаетесь с друзьями?
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_14,
    target_colname=utils.constants.TARGET,
    figsize=(20, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 15. Есть ли у Вас домашние питомцы? (да/нет)
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_15,
    target_colname=utils.constants.TARGET,
    figsize=(12, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 16. В течение последних 7 дней, как часто Вы практиковали тяжелые физические нагрузки?
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_16,
    target_colname=utils.constants.TARGET,
    figsize=(12, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 17. В течение последних 7 дней, как часто Вы практиковали умеренные физические нагрузки?
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_17,
    target_colname=utils.constants.TARGET,
    figsize=(12, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 18. В течение последних 7 дней, как часто Вы ходили пешком минимум 10 минут без перерыва?
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_18,
    target_colname=utils.constants.TARGET,
    figsize=(12, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 19. Уровень Вашего образования?
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_19,
    target_colname=utils.constants.TARGET,
    figsize=(25, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 20. Каков уровень образования Вашего партнёра? (если применимо)
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_20,
    target_colname=utils.constants.TARGET,
    figsize=(25, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 22. Как долго Вы проживаете в этом месте? (в годах)
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.num_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_22,
    target_colname=utils.constants.TARGET,
    figsize=(22, 6),
)
axes[2].set_xticks(axes[2].get_xticks(), axes[2].get_xticklabels(), rotation=15, ha='right')
plt.show()
# Out:
# t-критерий Стьюдента: Выборки различимы (p-значение: 0.000)

# %% [markdown]
# ### 23. Каков тип Вашего дома?
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_23,
    target_colname=utils.constants.TARGET,
    figsize=(19, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 24. Если Вы живёте в многоквартирном доме, то на каком этаже?
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.num_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_22,
    target_colname=utils.constants.TARGET,
    figsize=(22, 6),
    histplot_args={'discrete': True},
)
axes[2].set_xticks(axes[2].get_xticks(), axes[2].get_xticklabels(), rotation=15, ha='right')
plt.show()
# Out:
# t-критерий Стьюдента: Выборки различимы (p-значение: 0.000)

# %% [markdown]
# ### 25. Каким транспортом Вы обычно пользуетесь?
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_25,
    target_colname=utils.constants.TARGET,
    figsize=(25, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 26. Сколько времени занимает Ваш путь до работы в одну сторону?
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_26,
    target_colname=utils.constants.TARGET,
    figsize=(18, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 27. Каков тип Вашей занятости?
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_27,
    target_colname=utils.constants.TARGET,
    figsize=(19, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 28. Каковы Ваши предпочтения в пище?
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_28,
    target_colname=utils.constants.TARGET,
    figsize=(27, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 29. Каков тип Вашего питания?
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_29,
    target_colname=utils.constants.TARGET,
    figsize=(35, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 30. Вы курите? (да/нет)
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_30,
    target_colname=utils.constants.TARGET,
    figsize=(12, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 31. Количество родов
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.num_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_31,
    target_colname=utils.constants.TARGET,
    figsize=(12, 6),
    histplot_args={'discrete': True},
)
plt.show()
# Out:
# t-критерий Стьюдента: Выборки различимы (p-значение: 0.000)

# %% [markdown]
# ### 32. Количество прерванных беременностей
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.num_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_32,
    target_colname=utils.constants.TARGET,
    figsize=(12, 6),
    histplot_args={'discrete': True},
)
plt.show()
# Out:
# t-критерий Стьюдента: Выборки различимы (p-значение: 0.000)

# %% [markdown]
# ### 33. Гинекологические заболевания (да/нет)
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_33,
    target_colname=utils.constants.TARGET,
    figsize=(12, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 34. Заболевания щитовидной железы (да/нет)
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_34,
    target_colname=utils.constants.TARGET,
    figsize=(12, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ### 35. Наследственность (да/нет)
#
# [Навигация](#Навигация)

# %%
fig, axes = viz.cat_feature_report(
    data=df,
    feature_colname=utils.constants.QUESTION_35,
    target_colname=utils.constants.TARGET,
    figsize=(12, 6),
)
for ax in axes:
    ax.set_xticks(ax.get_xticks(), ax.get_xticklabels(), rotation=15, ha='right')
plt.show()

# %% [markdown]
# ## Точки данных с противоречивыми признаками
#
# [Навигация](#Навигация)

# %%
old_num = df.shape[0]

# %% [markdown]
# ### 4. Если имеете супруга или партнёра, как долго вы живёте вместе? (в годах)
#
# По идее, для данного признака недопустимо иметь значения NaN в тех точках, которые в Признаке 3 (Семейное положение) имели значения 'замужем', 'имею гражданского супруга'. А те точки данных, что в Признаке 3 имеют значения 'одинока', 'разведена', 'вдова' в этом признаке должны иметь значения NaN.
#
# Возможно это связано с тем, что Признак 3 некорректно составлен. На него нужно дать один ответ, хотя верными могут быть несколько. Например, женщина может быть вдовой и при этом иметь гражданского супруга, и т.п.

# %%
num = df.loc[(df[utils.constants.QUESTION_3].isin([utils.constants.ANSWER_3_1, utils.constants.ANSWER_3_2])), utils.constants.QUESTION_4].isna().sum()
print(f'Имеют в Признаке 3 "замужем"/"имею гражданского супруга", но НЕ ИМЕЮТ значения в Признаке 4 - {num} шт.')
num = df.loc[(df[utils.constants.QUESTION_3].isin([utils.constants.ANSWER_3_3, utils.constants.ANSWER_3_4, utils.constants.ANSWER_3_5])), utils.constants.QUESTION_4].notna().sum()
print(f'Имеют в Признаке 3 "одинока"/"разведена"/"вдова", но ИМЕЮТ значения в Признаке 4 - {num} шт.')
# Out:
# Имеют в Признаке 3 "замужем"/"имею гражданского супруга", но НЕ ИМЕЮТ значения в Признаке 4 - 37 шт.
# Имеют в Признаке 3 "одинока"/"разведена"/"вдова", но ИМЕЮТ значения в Признаке 4 - 11 шт.

# %%
index = df[(df[utils.constants.QUESTION_3].isin([utils.constants.ANSWER_3_1, utils.constants.ANSWER_3_2])) & (df[utils.constants.QUESTION_4].isna())].index
drop_df = df.drop(index=index)
index = df[(df[utils.constants.QUESTION_3].isin([utils.constants.ANSWER_3_3, utils.constants.ANSWER_3_4, utils.constants.ANSWER_3_5])) & (df[utils.constants.QUESTION_4].notna())].index
drop_df = drop_df.drop(index=index)

# %% [markdown]
# ### 7. Если да, как часто вы общаетесь?
#
# По идее для точек, которые в Признаке 6 (Жив ли хотя бы один из Ваших родителей?) имели значение 'да', должно быть значение в данном Признаке. С этим всё в порядке. И наоборот для точек, которые в Признаке 6 имели значение 'нет', не должно быть значения. Такая точка есть.

# %%
num = df.loc[df[utils.constants.QUESTION_6] == utils.constants.YES, utils.constants.QUESTION_7].isna().sum()
print(f'Имеют в Признаке 6 "да", но НЕ ИМЕЮТ значения в Признаке 7 - {num} шт.')
num = df.loc[df[utils.constants.QUESTION_6] == utils.constants.NO, utils.constants.QUESTION_7].notna().sum()
print(f'Имеют в Признаке 6 "нет", но ИМЕЮТ значения в Признаке 7 - {num} шт.')
# Out:
# Имеют в Признаке 6 "да", но НЕ ИМЕЮТ значения в Признаке 7 - 0 шт.
# Имеют в Признаке 6 "нет", но ИМЕЮТ значения в Признаке 7 - 1 шт.

# %%
index = df[(df[utils.constants.QUESTION_6] == utils.constants.NO) & (df[utils.constants.QUESTION_7].notna())].index
drop_df = drop_df.drop(index=index)

# %% [markdown]
# ### 9. Если да, сколько?
#
# По идее для точек, которые в Признаке 8 (Есть ли у Вас дети?) имели значение 'да', должно быть значение в данном Признаке. С этим всё в порядке. И наоборот для точек, которые в Признаке 8 имели значение 'нет', не должно быть значения. Такая точка есть.

# %%
num = df.loc[df[utils.constants.QUESTION_8] == utils.constants.YES, utils.constants.QUESTION_9].isna().sum()
print(f'Имеют в Признаке 8 "да", но НЕ ИМЕЮТ значения в Признаке 9 - {num} шт.')
num = df.loc[df[utils.constants.QUESTION_8] == utils.constants.NO, utils.constants.QUESTION_9].notna().sum()
print(f'Имеют в Признаке 8 "нет", но ИМЕЮТ значения в Признаке 9 - {num} шт.')
# Out:
# Имеют в Признаке 8 "да", но НЕ ИМЕЮТ значения в Признаке 9 - 0 шт.
# Имеют в Признаке 8 "нет", но ИМЕЮТ значения в Признаке 9 - 1 шт.

# %%
index = df[(df[utils.constants.QUESTION_8] == utils.constants.NO) & (df[utils.constants.QUESTION_9].notna())].index
index = index.intersection(drop_df.index)
drop_df = drop_df.drop(index=index)

# %% [markdown]
# ### 10. Есть ли у Вас совершеннолетние дети? (да/нет)
#
# С этим Признаком совсем всё плохо: стоит только взглянуть на распределение ответов.

# %%
viz.plot_pies(df, utils.constants.QUESTION_10, utils.constants.TARGET)

# %% [markdown]
# ### 11. Если да, как часто вы общаетесь?

# %%
num = df.loc[df[utils.constants.QUESTION_10] == utils.constants.YES, utils.constants.QUESTION_11].isna().sum()
print(f'Имеют в Признаке 10 "да", но НЕ ИМЕЮТ значения в Признаке 11 - {num} шт.')
num = df.loc[df[utils.constants.QUESTION_10] == utils.constants.NO, utils.constants.QUESTION_11].notna().sum()
print(f'Имеют в Признаке 10 "нет", но ИМЕЮТ значения в Признаке 11 - {num} шт.')
# Out:
# Имеют в Признаке 10 "да", но НЕ ИМЕЮТ значения в Признаке 11 - 0 шт.
# Имеют в Признаке 10 "нет", но ИМЕЮТ значения в Признаке 11 - 22 шт.

# %%
index = df[(df[utils.constants.QUESTION_10] == utils.constants.NO) & (df[utils.constants.QUESTION_11].notna())].index
index = index.intersection(drop_df.index)
drop_df = drop_df.drop(index=index)

# %% [markdown]
# ### 20. Каков уровень образования Вашего партнёра? (если применимо)

# %%
num = df.loc[df[utils.constants.QUESTION_3].isin([utils.constants.ANSWER_3_1, utils.constants.ANSWER_3_2]), utils.constants.QUESTION_20].isna().sum()
print(f'Имеют в Признаке 3 "замужем"/"имею гражданского супруга", но НЕ ИМЕЮТ значения в Признаке 20 - {num} шт.')
num = df.loc[df[utils.constants.QUESTION_3].isin([utils.constants.ANSWER_3_3, utils.constants.ANSWER_3_4, utils.constants.ANSWER_3_5]), utils.constants.QUESTION_20].notna().sum()
print(f'Имеют в Признаке 3 "одинока"/"разведена"/"вдова", но ИМЕЮТ значения в Признаке 20 - {num} шт.')
# Out:
# Имеют в Признаке 3 "замужем"/"имею гражданского супруга", но НЕ ИМЕЮТ значения в Признаке 20 - 12 шт.
# Имеют в Признаке 3 "одинока"/"разведена"/"вдова", но ИМЕЮТ значения в Признаке 20 - 43 шт.

# %%
index = df[(df[utils.constants.QUESTION_3].isin([utils.constants.ANSWER_3_1, utils.constants.ANSWER_3_2])) & (df[utils.constants.QUESTION_20].isna())].index
index = index.intersection(drop_df.index)
drop_df = drop_df.drop(index=index)
index = df[(df[utils.constants.QUESTION_3].isin([utils.constants.ANSWER_3_3, utils.constants.ANSWER_3_4, utils.constants.ANSWER_3_5])) & (df[utils.constants.QUESTION_20].notna())].index
index = index.intersection(drop_df.index)
drop_df = drop_df.drop(index=index)

# %% [markdown]
# ### 24. Если Вы живёте в многоквартирном доме, то на каком этаже?

# %%
num = df.loc[df[utils.constants.QUESTION_23] == utils.constants.ANSWER_23_1, utils.constants.QUESTION_24].isna().sum()
print(f'Имеют в Признаке 23 "многоквартирный дом", но НЕ ИМЕЮТ значения в Признаке 24 - {num} шт.')
num = df.loc[(df[utils.constants.QUESTION_23].isin([utils.constants.ANSWER_23_2, utils.constants.ANSWER_23_3])), utils.constants.QUESTION_24].notna().sum()
print(f'Имеют в Признаке 23 "таунхаус"/"собственный дом", но ИМЕЮТ значения в Признаке 24 - {num} шт.')
# Out:
# Имеют в Признаке 23 "многоквартирный дом", но НЕ ИМЕЮТ значения в Признаке 24 - 1 шт.
# Имеют в Признаке 23 "таунхаус"/"собственный дом", но ИМЕЮТ значения в Признаке 24 - 10 шт.

# %%
index = df[(df[utils.constants.QUESTION_23] == utils.constants.ANSWER_23_1) & (df[utils.constants.QUESTION_24].isna())].index
index = index.intersection(drop_df.index)
drop_df = drop_df.drop(index=index)
index = df[(df[utils.constants.QUESTION_23].isin([utils.constants.ANSWER_23_2, utils.constants.ANSWER_23_3])) & (df[utils.constants.QUESTION_24].notna())].index
index = index.intersection(drop_df.index)
drop_df = drop_df.drop(index=index)

# %% [markdown]
# ### 26. Сколько времени занимает Ваш путь до работы в одну сторону?

# %%
num = df.loc[df[utils.constants.QUESTION_27].isin([utils.constants.ANSWER_27_1, utils.constants.ANSWER_27_2]), utils.constants.QUESTION_26].isna().sum()
print(f'Имеют в Признаке 27 "полный рабочий день"/"частичная занятость", но НЕ ИМЕЮТ значения в Признаке 26 - {num} шт.')
num = df.loc[df[utils.constants.QUESTION_27].isin([utils.constants.ANSWER_27_3, utils.constants.ANSWER_27_4]), utils.constants.QUESTION_26].notna().sum()
print(f'Имеют в Признаке 27 "я работаю из дома"/"я не работаю", но ИМЕЮТ значения в Признаке 26 - {num} шт.')
# Out:
# Имеют в Признаке 27 "полный рабочий день"/"частичная занятость", но НЕ ИМЕЮТ значения в Признаке 26 - 1 шт.
# Имеют в Признаке 27 "я работаю из дома"/"я не работаю", но ИМЕЮТ значения в Признаке 26 - 16 шт.

# %%
index = df[(df[utils.constants.QUESTION_27].isin([utils.constants.ANSWER_27_1, utils.constants.ANSWER_27_2])) & (df[utils.constants.QUESTION_26].isna())].index
index = index.intersection(drop_df.index)
drop_df = drop_df.drop(index=index)
index = df[(df[utils.constants.QUESTION_27].isin([utils.constants.ANSWER_27_3, utils.constants.ANSWER_27_4])) & (df[utils.constants.QUESTION_26].notna())].index
index = index.intersection(drop_df.index)
drop_df = drop_df.drop(index=index)

# %%
new_num = drop_df.shape[0]

# %%
print(f'Количество точек, включая протеворечивые - {old_num}.')
print(f'Количество точек без протеворечивых - {new_num}.')
print(f'В случае их исключения теряем {old_num - new_num} точек ({(old_num - new_num)/ old_num:.2%}).')
# Out:
# Количество точек, включая протеворечивые - 595.
# Количество точек без протеворечивых - 468.
# В случае их исключения теряем 127 точек (21.34%).

# %% [markdown]
# ## Корреляция Пирсона между численными признаками
#
# [Навигация](#Навигация)

# %%
tmp = df[utils.constants.NUMERICAL_FEATURES].copy()
tmp.rename(columns={
    utils.constants.QUESTION_2: 'Признак №2',
    utils.constants.QUESTION_4: 'Признак №4',
    utils.constants.QUESTION_22: 'Признак №22',
    utils.constants.QUESTION_24: 'Признак №24',
}, inplace=True)

# %%
ax = sns.heatmap(
    tmp.corr(method='spearman'),
    mask=np.triu(np.ones_like(tmp.corr(), dtype=bool)),
    annot=True,
    cbar=False,
)
